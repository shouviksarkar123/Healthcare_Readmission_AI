# %% [markdown]
# # Patient Readmission – Job Orchestration Overview
#
# ## Objective
# This notebook documents the Databricks Job workflow used to run
# the end-to-end patient readmission pipeline.
#
# ## Orchestration Method
# - Implemented using Databricks Workflows (Jobs UI)
# - Tasks are notebook-based
# - Dependencies are managed visually in the Job graph
#
# ## Pipeline Flow
# 1. bronze_ingestion
# 2. silver_transformation
# 3. gold_features
# 4. ml_training
#
# ## Execution Mode
# - Manual trigger
# - Can be scheduled (daily / hourly) if required

# %%
# Reference only – actual orchestration is handled via Jobs UI

job_tasks = [
    "01_Bronze/bronze_ingestion",
    "02_Silver/silver_transformation",
    "03_Gold/gold_features",
    "04_MLflow/ml_training"
]

job_tasks
